# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("yolov8session"):
  os.makedirs("yolov8session")

# %%
# %cd yolov8session
# Out:
# /content/gdrive/MyDrive/yolov8session

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.

# %%
# %cd ultralytics
# Out:
# /content/gdrive/MyDrive/yolov8session/ultralytics

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 23.8 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 58.1ms
# Speed: 14.8ms preprocess, 58.1ms inference, 40.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# !yolo predict model=yolov8x.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 65.2ms
# Speed: 12.0ms preprocess, 65.2ms inference, 25.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo predict model=yolov8x.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg: 448x640 14 persons, 1 backpack, 6 handbags, 1 bottle, 66.0ms
# Speed: 2.5ms preprocess, 66.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %%
# !yolo predict model=yolov8x.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# video 1/1 (1/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 (no detections), 63.9ms
# video 1/1 (2/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 (no detections), 38.6ms
# video 1/1 (3/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 1 person, 38.0ms
# video 1/1 (4/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 5 persons, 37.7ms
# video 1/1 (5/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 10 persons, 32.1ms
# video 1/1 (6/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 11 persons, 30.5ms
# video 1/1 (7/4095) /content/gdrive/MyDrive/yolov8session/ultralytics/pw.mp4: 384x640 14 persons, 31.2ms
# ...

# %%
# !yolo mode = predict task=segment model=yolov8x-seg.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg: 448x640 16 persons, 1 backpack, 7 handbags, 71.1ms
# Speed: 2.9ms preprocess, 71.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
# !yolo mode=predict task=segment model=yolov8x-seg.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients
#
# video 1/1 (1/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 9 persons, 1 backpack, 3 handbags, 82.3ms
# video 1/1 (2/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 7 persons, 1 backpack, 4 handbags, 49.0ms
# video 1/1 (3/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 7 persons, 1 backpack, 2 handbags, 48.3ms
# video 1/1 (4/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 8 persons, 1 backpack, 1 handbag, 46.7ms
# video 1/1 (5/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 8 persons, 1 backpack, 1 handbag, 37.2ms
# video 1/1 (6/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 384x640 10 persons, 1 backpack, 3 handbags, 38.1ms
# ...

# %%
# !yolo mode = predict task=classify model=yolov8x-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-cls summary (fused): 133 layers, 57404200 parameters, 0 gradients
#
# image 1/1 /content/gdrive/MyDrive/yolov8session/ultralytics/people.jpeg: 224x224 jean 0.13, street_sign 0.08, unicycle 0.07, miniskirt 0.05, traffic_light 0.04, 14.3ms
# Speed: 8.1ms preprocess, 14.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict

# %%
# !yolo mode = predict task=classify model=yolov8x-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-cls summary (fused): 133 layers, 57404200 parameters, 0 gradients
#
# video 1/1 (1/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.34, bearskin 0.19, mortarboard 0.04, torch 0.03, whistle 0.03, 14.1ms
# video 1/1 (2/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.42, bearskin 0.11, mortarboard 0.03, rugby_ball 0.02, drum 0.02, 14.2ms
# video 1/1 (3/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.49, mortarboard 0.04, rugby_ball 0.04, bearskin 0.03, whistle 0.03, 14.2ms
# video 1/1 (4/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.41, rugby_ball 0.06, mortarboard 0.05, whistle 0.03, bearskin 0.02, 14.1ms
# ...

# %%
# !yolo task=classify mode=predict task=classify source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4'
# Out:
# ...
# 100% 5.28M/5.28M [00:01<00:00, 4.38MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# video 1/1 (1/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 bearskin 0.30, academic_gown 0.26, mortarboard 0.03, trombone 0.03, panpipe 0.03, 2.8ms
# video 1/1 (2/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 bearskin 0.62, academic_gown 0.13, trombone 0.01, panpipe 0.01, mortarboard 0.01, 4.3ms
# video 1/1 (3/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 bearskin 0.30, academic_gown 0.20, ping-pong_ball 0.02, trombone 0.02, mortarboard 0.02, 3.6ms
# video 1/1 (4/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 bearskin 0.32, academic_gown 0.25, cello 0.03, mortarboard 0.02, panpipe 0.02, 3.6ms
# ...

# %%
# !yolo mode = predict task=classify model=yolov8l-cls.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4'
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-cls summary (fused): 133 layers, 37465576 parameters, 0 gradients
#
# video 1/1 (1/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.20, basketball 0.10, torch 0.10, bearskin 0.08, ballplayer 0.04, 11.2ms
# video 1/1 (2/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.76, mortarboard 0.04, basketball 0.04, bearskin 0.01, vestment 0.01, 10.9ms
# video 1/1 (3/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.73, mortarboard 0.05, vestment 0.02, basketball 0.02, torch 0.02, 10.9ms
# video 1/1 (4/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 224x224 academic_gown 0.71, mortarboard 0.03, vestment 0.03, accordion 0.02, bearskin 0.02, 10.9ms
# ...

# %%
# !yolo mode=predict task=pose model=yolov8x-pose-p6.pt source='/content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4'
# Out:
# ...
# 100% 190M/190M [00:10<00:00, 18.7MB/s]
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-pose-p6 summary (fused): 375 layers, 99141280 parameters, 0 gradients
#
# video 1/1 (1/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 13 persons, 134.5ms
# video 1/1 (2/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 12 persons, 126.1ms
# video 1/1 (3/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 10 persons, 125.9ms
# video 1/1 (4/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 9 persons, 126.8ms
# video 1/1 (5/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 10 persons, 125.6ms
# video 1/1 (6/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 10 persons, 125.1ms
# video 1/1 (7/720) /content/gdrive/MyDrive/yolov8session/ultralytics/people.mp4: 768x1280 9 persons, 125.9ms
# ...

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom_data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.106 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
